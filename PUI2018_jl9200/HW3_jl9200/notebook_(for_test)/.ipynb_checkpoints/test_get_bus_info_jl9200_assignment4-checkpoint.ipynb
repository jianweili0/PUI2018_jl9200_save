# %%
from __future__ import print_function
import requests
import json
import csv

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

###
# go to terminal
# python get_bus_info_jl9200.py API_KEY Busline Busline.csv

# %%
MY_KEY ="22d5bcc9-a3c0-4858-94fb-2e1e8c04add9" # sys.argv[1]
BUS = "M5"  # sys.argv[2]
## input will be "python show_bus_locations.py <MTA_KEY> <BUS_LINE>"

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key="+ MY_KEY + "&VehicleMonitoringDetailLevel=calls&LineRef=" + BUS

print (url)
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=22d5bcc9-a3c0-4858-94fb-2e1e8c04add9&VehicleMonitoringDetailLevel=calls&LineRef=M5

# %%
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
print (data)
# Out:
# {u'Siri': {u'ServiceDelivery': {u'SituationExchangeDelivery': [{u'Situations': {u'PtSituationElement': [{u'Description': u'Expect delays on buses that serve Midtown East during the United Nations General Assembly this week.', u'Consequences': {u'Consequence': [{u'Condition': u'delayed'}]}, u'Affects': {u'VehicleJourneys': {u'AffectedVehicleJourney': [{u'DirectionRef': u'0', u'LineRef': u'MTABC_BM1'}, {u'DirectionRef': u'1', u'LineRef': u'MTABC_BM1'}, {u'DirectionRef': u'0', u'LineRef': u'MTABC_BM3'}, {u'DirectionRef': u'1', u'LineRef': u'MTABC_BM3'}, {u'DirectionRef': u'0', u'LineRef': u'MTABC_BM4'}, {u'DirectionRef': u'1', u'LineRef': u'MTABC_BM4'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M1'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M1'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M1'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M1'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M10'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M10'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M100'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M100'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M101'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M101'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M101'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M101'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M102'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M102'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M103'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M103'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M104'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M104'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M106'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M106'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M11'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M11'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M116'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M116'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M12'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M12'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M14A'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M14A'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M14D'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M14D'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M15'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M15'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M15+'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M15+'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M2'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M2'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M2'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M2'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M20'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M20'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M21'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M21'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M22'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M22'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M23+'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M23+'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M3'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M3'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M31'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M31'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M34+'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M34+'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M34A+'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M34A+'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M35'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M35'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M4'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M4'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M4'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_M4'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_M42'}, {u'DirectionRef': u'1', u'LineR ...

# %%
# make bus_status_info function
# don't run
print(Num_bus)
# test print in notebook
for i in range(Num_bus):
    bus_lat = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
    bus_lon = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
    Stop_Name = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName']
    Stop_Status = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
    print("%s,%s,%s,%s"%(bus_lat,bus_lon,Stop_Name,Stop_Status))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-b17a835c824a> in <module>()
#       1 # make bus_status_info function
#       2 # don't run
# ----> 3 print(Num_bus)
#       4 # test print in notebook
#       5 for i in range(Num_bus):
#
# NameError: name 'Num_bus' is not defined

# %%
filename = BUS +".csv"

# filename will be sys.argv[3]

def bus_status_info_csv():          
    with open(str(filename),'w') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(['Latitude','Longitude','Stop Name','Stop Status'])
        Num_bus = len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
        if Num_bus == 0:
            row = str('No Data')
            writer.writerow([row])
        else:
            for i in range(Num_bus):        
                bus_lat = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
                bus_lon = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
                checkEmpty = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']
                if len(checkEmpty) == 0:
                    Stop_Name = "N/A"
                    Stop_Status = "N/A"
                else:  
                    Stop_Name = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName']
                    Stop_Status = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']

                # need to convert as str
                row = str(bus_lat),str(bus_lon),str(Stop_Name),str(Stop_Status)
                writer.writerow(row)

# %%
# test incase the bus route didn't exist
try:  
    test = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
    bus_status_info_csv()
except KeyError:
    print('No such route')
